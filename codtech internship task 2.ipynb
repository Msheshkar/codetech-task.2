# %%
# !pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.14.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from SpeechRecognition) (4.15.0)
# Downloading speechrecognition-3.14.4-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 59.2 MB/s eta 0:00:00
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.14.4

# %%
import speech_recognition as sr

# %%
from pydub import AudioSegment

audio = AudioSegment.from_file("audio.mp3")
audio.export("audio.wav", format="wav")
# Out:
# <_io.BufferedRandom name='audio.wav'>

# %%
import speech_recognition as sr

r = sr.Recognizer()

with sr.AudioFile("audio.wav") as source:
    audio_data = r.record(source)

print(r.recognize_google(audio_data))
# Out:
# natural language processing is a branch of artificial intelligence that helps computer understand human language it is widely used in applications like chatbot translators Vice assistant and text summarization

# %% [markdown]
# The uploaded audio file was verified, converted into WAV format, and successfully transcribed using a pre-trained speech recognition model.
